# %%
from worldsense.benchmark import load_testset

testset_dir = "data/other_tests/memorisation"
trials_df = load_testset(testset_dir)  # Load all trials as a pandas dataframe

# %%
print(trials_df.tail()['text'])  # Display the first few rows of the dataframe
# Out:
# 11227    Watching a car race today, Freddy bet with his...
# 11228    Over the years, Ted and Lisa plan to renovate ...
# 11229    Over the years, Ted and Lisa plan to renovate ...
# 11230    Jimmy went to the mall with a list of 5 items ...
# 11231    Jimmy went to the mall with a list of 5 items ...
# Name: text, dtype: object

# %%
import random as rd

# %%
df_list = trials_df.to_dict(orient='records')
rd.sample(df_list, 2)
# Out:
# [{'Key': 6196701747143722826,
#   'problemname': 'Consist.normal',
#   'tuple_ID': 'finetune_10k_results_09-26-2023_02h18m04s_2139',
#   'text': "Since she got her new job Alice visited a different country each year. In total, she visited 3 countries.\nIf one were to say: 'Alice visited Italy after Australia, Italy in between her visits to Australia and United Kingdom and Italy in between her visits to Australia and United Kingdom.', would that situation be POSSIBLE or IMPOSSIBLE ? Only respond with 'POSSIBLE' or 'IMPOSSIBLE' without any explanation:\n",
#   'expectedresp': ['POSSIBLE', 'IMPOSSIBLE'],
#   'span': 2,
#   'descr': '[(0, 1),(1, 0, 2),(1, 0, 2)]',
#   'query': '(1, 0, 2)',
#   'objects': ['Australia', 'Italy', 'United Kingdom'],
#   'problemsize': 3,
#   'skin': 'trips_countries',
#   'qskin': 'directQ2',
#   'complexity': 'Complexity_2',
#   'query_len': 3,
#   'goldresp': 'POSSIBLE',
#   'EXPNAME': 'memorisation',
#   'EXP_i': 10118},
#  {'Key': -7002141528012908152,
# ...

# %%
rd.choices(trials_df, k=5)  # Randomly select 5 trials from the dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5754
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [61], in <module>
# ----> 1 rd.choices(trials_df, k=5)
#
# ...

# %%
other_tests = dict()
for test in os.listdir("./data/other_tests"):
    other_tests[test] = load_testset(f"./data/other_tests/{test}")

# %%
other_tests['ood-problem']
# Out:
#                       Key     problemname  \
# 0    -8835267129707233372  Infer.parallel
# 1     2745962097812763947  Infer.parallel
# 2    -6756389878991767128  Infer.parallel
# 3    -3523887513001861005  Infer.parallel
# 4     5992111034333909673  Infer.parallel
# ...                   ...             ...
# 5395 -7183380611663591617  Infer.parallel
# 5396  5380719760124466835  Infer.parallel
# 5397 -2920286265969399907  Infer.parallel
# 5398 -2190767055205383208  Infer.parallel
# 5399 -2573984890252519464  Infer.parallel
#
#                                         tuple_ID  \
# 0     parallel_results_10-31-2023_07h23m44s_1552
# 1     parallel_results_10-31-2023_07h23m44s_1552
# 2     parallel_results_10-31-2023_07h23m44s_2608
# 3     parallel_results_10-31-2023_07h23m44s_2608
# 4     parallel_results_10-31-2023_07h23m44s_1851
# ...                                          ...
# 5395  parallel_results_10-31-2023_07h23m44s_1499
# 5396   parallel_results_10-31-2023_07h23m44s_605
# ...

# %%
trials_df.head() # Display the last few rows of the dataframe
# Out:
#                    Key     problemname  \
# 0  7959848182580870883  Consist.normal
# 1  2294099916193274578  Consist.normal
# 2  9125316811816168734    Infer.normal
# 3  3852224435590882595    Infer.normal
# 4  1276804373760883065  Consist.normal
#
#                                          tuple_ID  \
# 0  finetune_10k_results_09-26-2023_02h18m04s_1961
# 1  finetune_10k_results_09-26-2023_02h18m04s_1961
# 2   finetune_10k_results_09-26-2023_02h18m04s_249
# 3   finetune_10k_results_09-26-2023_02h18m04s_249
# 4  finetune_10k_results_09-26-2023_02h18m04s_2321
#
#                                                 text            expectedresp  \
# 0  At the post office, Max's job is to sort the i...  [POSSIBLE, IMPOSSIBLE]
# 1  At the post office, Max's job is to sort the i...  [POSSIBLE, IMPOSSIBLE]
# 2  There are 3 pieces of furniture to load into t...           [TRUE, FALSE]
# 3  There are 3 pieces of furniture to load into t...           [TRUE, FALSE]
# ...

# %%
all(map(lambda x : x.isdigit() or x.isalpha(), trials_df['goldresp']))
# Out:
# True

# %%
list(filter(lambda x : '_' not in x, dir(str)))
# Out:
# ['capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
os.path.join(testset_dir, 'trials.csv')
# Out:
# 'data/worldsense/test_set/trials.csv'

# %%
'ABc12'.lower()
# Out:
# 'abc12'

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
set.difference({'a', 'b'}, {'b', 'c'})
# Out:
# {'a'}

# %%
import time

# %%
split(8, 3)
# Out:
# [3, 2, 3]

# %%
int(0.6)
# Out:
# 0
